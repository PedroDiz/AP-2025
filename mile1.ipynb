# %% [markdown]
# #Data download + PNG resize (CPU)

# %% [markdown]
# **Load the dataset ISIC(collection 66, representative of the training set of task 3) into the *results* variable** , ~10k entries

# %%
import requests

# Base endpoint
base_url = "https://api.isic-archive.com/api/v2/images/search/"
params = {
    "collections": "66,67,73"
}

# Loop until no more pages
all_ids = []
results = []

page = 1

while True:
   # print(f"Requesting page {page}...")
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract image IDs
    for result in data.get("results", []):
        all_ids.append(result["isic_id"])
        results.append(result)

    # Print first ID for confirmation
    #print("image ID:", all_ids[(page-1)*100])

    # Prepare for next page
    next_cursor = data.get("next")
    if not next_cursor:
        break  # we're done!

    # Update URL for the next request
    base_url = next_cursor
    params = {}  # cursor URL already includes params
    page += 1

print(f"Total images collected: {len(all_ids)}")
# Out:
# Total images collected: 11720

# %% [markdown]
# **Analysing the data**

# %%
results[0]
# Out:
# {'isic_id': 'ISIC_0036064',
#  'copyright_license': 'CC-BY-NC',
#  'attribution': 'MILK study team',
#  'files': {'full': {'url': 'https://content.isic-archive.com/95724593-18b2-4e93-b947-89b2309f3b47/57647d76-d7ba-4054-8119-184e6376d984.jpg?Expires=1746662400&Signature=N~2rVb8V0uB8Nxc4TRlkRNSaxIRqLEAer2VyG00qb0u3Zunq3FKNLVbvJ7pwdo9oLR~awfHJ13P3nL2JYUUiCESJItGFlfb3u1Ym4QGNx~ieyTY57mMgez~B1ADQj1sbLdjmFzBmu5M4uMQlFmalEiq6BZ5lLD3re1xFh7ZC9BPnpBA45o9u49M-7un3wvUvX1R34g3xoBjnFG2IyIdfcmNeZxOX~DN~o14XsdQUtapzfUyHEYgvln7t8lQpTQohB0G~2sA2PqbRs03mWh0trY38r1hacLGXeDwS~OxX6L7LlX9ZdMD-KvWugFbnjZrLRd9jz9z0ciK~kah-Zacmeg__&Key-Pair-Id=K3KFHCM130RXTL',
#    'size': 20930},
#   'thumbnail_256': {'url': 'https://content.isic-archive.com/3fe9d80d-eb4e-403f-9a6b-6aaffb37c265/ISIC_0036064_thumbnail_256.jpg?Expires=1746662400&Signature=h3h25SmAx-rct0V3WngQTGTr1dyrfB2LSZpF3hditv1gS8avyarwP6VwNorQ7vT2uEbWCzBOn-rjDAiOgob7fwsvCyicaO4s2Bc---o8YkNPwcmgRH1kLklDGZcEMd3hYJM92rycteVlwuGbfxVtdMDVTxO9ZOembGkr7gtr2967KGOgXYr4shwOfGuWPmBbRVBtxkLYUd2vIylnfP6JVVe3L1RJ96dLAoQoCNh4dCFv6yB-6wp4K7W7v4eaeOLJzB66Qj1n0w1RenqbmX56jYOcVONK2KtaRqlU3EcipDU3GBo9bCT8uPlQB1nBCVV4-mmOjH~LoFzYDZpnhFbLCA__&Key-Pair-Id=K3KFHCM130RXTL',
#    'size': 5283}},
#  'metadata': {'acquisition': {'pixels_x': 600,
#    'pixels_y': 450,
#    'image_type': 'dermoscopic'},
#   'clinical': {'concomitant_biopsy': True,
#    'diagnosis_1': 'Malignant',
#    'diagnosis_2': 'Malignant adnexal epithelial proliferations - Follicular',
#    'diagnosis_3': 'Basal cell carcinoma',
#    'diagnosis_confirm_type': 'histopathology',
#    'melanocytic': False,
#    'lesion_id': 'IL_4973744',
#    'diagnosis': 'basal cell carcinoma'}},
#  'public': True}

# %% [markdown]
# **We will confirm if every image is in the correct size (600x450)**

# %%
for result in results:
    try:
        pixels_x = result["metadata"]["acquisition"]["pixels_x"]
        pixels_y = result["metadata"]["acquisition"]["pixels_y"]
        if(pixels_x != 600 and pixels_y != 450):
          print("Incorrect Image ID:", result["isic_id"])
          print("pixel_X:", pixels_x, "pixel_Y:", pixels_y)
    except KeyError:
        print("Missing pixel data in one of the results.")

# %% [markdown]
# Since no image ID was printed, we can assume all the images have the correct size

# %% [markdown]
# **Download the photos into ISIC_IMAGES_TASK_3 folder**

# %%
import os

# Make sure the folder exists
os.makedirs("ISIC_IMAGES_TASK_3", exist_ok=True)

# Loop through all results
for result in results:
    try:
        isic_id = result["isic_id"]
        image_url = result["files"]["full"]["url"]
        file_path = os.path.join("ISIC_IMAGES_TASK_3", f"{isic_id}.jpg")

        print(f"Downloading {isic_id}...")

        # Download and save the image
        response = requests.get(image_url)
        if response.status_code == 200:
            with open(file_path, "wb") as f:
                f.write(response.content)
        else:
            print(f"Failed to download {isic_id}: HTTP {response.status_code}")
    except KeyError as e:
        print(f"Missing key {e} in one of the results.")
# Out:
# Downloading ISIC_0036064...
# Downloading ISIC_0036063...
# Downloading ISIC_0036062...
# Downloading ISIC_0036061...
# Downloading ISIC_0036060...
# Downloading ISIC_0036059...
# Downloading ISIC_0036058...
# Downloading ISIC_0036057...
# Downloading ISIC_0036056...
# Downloading ISIC_0036055...
# Downloading ISIC_0036054...
# Downloading ISIC_0036053...
# Downloading ISIC_0036052...
# Downloading ISIC_0036051...
# Downloading ISIC_0036050...
# Downloading ISIC_0036049...
# Downloading ISIC_0036048...
# Downloading ISIC_0036047...
# Downloading ISIC_0036046...
# Downloading ISIC_0036045...
# Downloading ISIC_0036044...
# Downloading ISIC_0036043...
# Downloading ISIC_0036042...
# Downloading ISIC_0036041...
# Downloading ISIC_0036040...
# Downloading ISIC_0036039...
# Downloading ISIC_0036038...
# Downloading ISIC_0036037...
# Downloading ISIC_0036036...
# Downloading ISIC_0036035...
# Downloading ISIC_0036034...
# Downloading ISIC_0036033...
# Downloading ISIC_0036032...
# Downloading ISIC_0036031...
# Downloading ISIC_0036030...
# Downloading ISIC_0036029...
# Downloading ISIC_0036028...
# Downloading ISIC_0036027...
# Downloading ISIC_0036026...
# Downloading ISIC_0036025...
# Downloading ISIC_0036024...
# Downloading ISIC_0036023...
# Downloading ISIC_0036022...
# Downloading ISIC_0036021...
# Downloading ISIC_0036020...
# Downloading ISIC_0036019...
# Downloading ISIC_0036018...
# Downloading ISIC_0036017...
# Downloading ISIC_0036016...
# Downloading ISIC_0036015...
# Downloading ISIC_0036014...
# Downloading ISIC_0036013...
# Downloading ISIC_0036012...
# Downloading ISIC_0036011...
# Downloading ISIC_0036010...
# Downloading ISIC_0036009...
# Downloading ISIC_0036008...
# Downloading ISIC_0036007...
# Downloading ISIC_0036006...
# Downloading ISIC_0036005...
# Downloading ISIC_0036004...
# Downloading ISIC_0036003...
# Downloading ISIC_0036002...
# Downloading ISIC_0036001...
# Downloading ISIC_0036000...
# Downloading ISIC_0035999...
# Downloading ISIC_0035998...
# Downloading ISIC_0035997...
# Downloading ISIC_0035996...
# Downloading ISIC_0035995...
# Downloading ISIC_0035994...
# Downloading ISIC_0035993...
# Downloading ISIC_0035992...
# Downloading ISIC_0035991...
# Downloading ISIC_0035990...
# Downloading ISIC_0035989...
# Downloading ISIC_0035988...
# Downloading ISIC_0035987...
# Downloading ISIC_0035986...
# Downloading ISIC_0035985...
# Downloading ISIC_0035984...
# Downloading ISIC_0035983...
# Downloading ISIC_0035982...
# Downloading ISIC_0035981...
# Downloading ISIC_0035980...
# Downloading ISIC_0035979...
# Downloading ISIC_0035978...
# Downloading ISIC_0035977...
# Downloading ISIC_0035976...
# Downloading ISIC_0035975...
# Downloading ISIC_0035974...
# Downloading ISIC_0035973...
# Downloading ISIC_0035972...
# Downloading ISIC_0035971...
# Downloading ISIC_0035970...
# Downloading ISIC_0035969...
# Downloading ISIC_0035968...
# Downloading ISIC_0035967...
# Downloading ISIC_0035966...
# Downloading ISIC_0035965...
# Downloading ISIC_0035964...
# Downloading ISIC_0035963...
# Downloading ISIC_0035962...
# Downloading ISIC_0035961...
# Downloading ISIC_0035960...
# Downloading ISIC_0035959...
# Downloading ISIC_0035958...
# Downloading ISIC_0035957...
# Downloading ISIC_0035956...
# Downloading ISIC_0035955...
# Downloading ISIC_0035954...
# Downloading ISIC_0035953...
# Downloading ISIC_0035952...
# Downloading ISIC_0035951...
# Downloading ISIC_0035950...
# Downloading ISIC_0035949...
# Downloading ISIC_0035948...
# Downloading ISIC_0035947...
# Downloading ISIC_0035946...
# Downloading ISIC_0035945...
# Downloading ISIC_0035944...
# Downloading ISIC_0035943...
# Downloading ISIC_0035942...
# Downloading ISIC_0035941...
# Downloading ISIC_0035940...
# Downloading ISIC_0035939...
# Downloading ISIC_0035938...
# Downloading ISIC_0035937...
# Downloading ISIC_0035936...
# Downloading ISIC_0035935...
# Downloading ISIC_0035934...
# Downloading ISIC_0035933...
# Downloading ISIC_0035932...
# Downloading ISIC_0035931...
# Downloading ISIC_0035930...
# Downloading ISIC_0035929...
# Downloading ISIC_0035928...
# Downloading ISIC_0035927...
# Downloading ISIC_0035926...
# Downloading ISIC_0035925...
# Downloading ISIC_0035924...
# Downloading ISIC_0035923...
# Downloading ISIC_0035922...
# Downloading ISIC_0035921...
# Downloading ISIC_0035920...
# Downloading ISIC_0035919...
# Downloading ISIC_0035918...
# Downloading ISIC_0035917...
# Downloading ISIC_0035916...
# Downloading ISIC_0035915...
# Downloading ISIC_0035914...
# Downloading ISIC_0035913...
# Downloading ISIC_0035912...
# Downloading ISIC_0035911...
# Downloading ISIC_0035910...
# Downloading ISIC_0035909...
# Downloading ISIC_0035908...
# Downloading ISIC_0035907...
# Downloading ISIC_0035906...
# Downloading ISIC_0035905...
# Downloading ISIC_0035904...
# Downloading ISIC_0035903...
# Downloading ISIC_0035902...
# Downloading ISIC_0035901...
# Downloading ISIC_0035900...
# Downloading ISIC_0035899...
# Downloading ISIC_0035898...
# Downloading ISIC_0035897...
# Downloading ISIC_0035896...
# Downloading ISIC_0035895...
# Downloading ISIC_0035894...
# Downloading ISIC_0035893...
# Downloading ISIC_0035892...
# Downloading ISIC_0035891...
# Downloading ISIC_0035890...
# Downloading ISIC_0035889...
# Downloading ISIC_0035888...
# Downloading ISIC_0035887...
# Downloading ISIC_0035886...
# Downloading ISIC_0035885...
# Downloading ISIC_0035884...
# Downloading ISIC_0035883...
# Downloading ISIC_0035882...
# Downloading ISIC_0035881...
# Downloading ISIC_0035880...
# Downloading ISIC_0035879...
# Downloading ISIC_0035878...
# Downloading ISIC_0035877...
# Downloading ISIC_0035876...
# Downloading ISIC_0035875...
# Downloading ISIC_0035874...
# Downloading ISIC_0035873...
# Downloading ISIC_0035872...
# Downloading ISIC_0035871...
# Downloading ISIC_0035870...
# Downloading ISIC_0035869...
# Downloading ISIC_0035868...
# Downloading ISIC_0035867...
# Downloading ISIC_0035866...
# Downloading ISIC_0035865...
# Downloading ISIC_0035864...
# Downloading ISIC_0035863...
# Downloading ISIC_0035862...
# Downloading ISIC_0035861...
# Downloading ISIC_0035860...
# Downloading ISIC_0035859...
# Downloading ISIC_0035858...
# Downloading ISIC_0035857...
# Downloading ISIC_0035856...
# Downloading ISIC_0035855...
# Downloading ISIC_0035854...
# Downloading ISIC_0035853...
# Downloading ISIC_0035852...
# Downloading ISIC_0035851...
# Downloading ISIC_0035850...
# Downloading ISIC_0035849...
# Downloading ISIC_0035848...
# Downloading ISIC_0035847...
# Downloading ISIC_0035846...
# Downloading ISIC_0035845...
# Downloading ISIC_0035844...
# Downloading ISIC_0035843...
# Downloading ISIC_0035842...
# Downloading ISIC_0035841...
# Downloading ISIC_0035840...
# Downloading ISIC_0035839...
# Downloading ISIC_0035838...
# Downloading ISIC_0035837...
# Downloading ISIC_0035836...
# Downloading ISIC_0035835...
# Downloading ISIC_0035834...
# Downloading ISIC_0035833...
# Downloading ISIC_0035832...
# Downloading ISIC_0035831...
# Downloading ISIC_0035830...
# Downloading ISIC_0035829...
# Downloading ISIC_0035828...
# Downloading ISIC_0035827...
# Downloading ISIC_0035826...
# Downloading ISIC_0035825...
# Downloading ISIC_0035824...
# Downloading ISIC_0035823...
# Downloading ISIC_0035822...
# Downloading ISIC_0035821...
# Downloading ISIC_0035820...
# Downloading ISIC_0035819...
# Downloading ISIC_0035818...
# Downloading ISIC_0035817...
# Downloading ISIC_0035816...
# Downloading ISIC_0035815...
# Downloading ISIC_0035814...
# Downloading ISIC_0035813...
# Downloading ISIC_0035812...
# Downloading ISIC_0035811...
# Downloading ISIC_0035810...
# Downloading ISIC_0035809...
# Downloading ISIC_0035808...
# Downloading ISIC_0035807...
# Downloading ISIC_0035806...
# Downloading ISIC_0035805...
# Downloading ISIC_0035804...
# Downloading ISIC_0035803...
# Downloading ISIC_0035802...
# Downloading ISIC_0035801...
# Downloading ISIC_0035800...
# Downloading ISIC_0035799...
# Downloading ISIC_0035798...
# Downloading ISIC_0035797...
# Downloading ISIC_0035796...
# Downloading ISIC_0035795...
# Downloading ISIC_0035794...
# Downloading ISIC_0035793...
# Downloading ISIC_0035792...
# Downloading ISIC_0035791...
# Downloading ISIC_0035790...
# Downloading ISIC_0035789...
# Downloading ISIC_0035788...
# Downloading ISIC_0035787...
# Downloading ISIC_0035786...
# Downloading ISIC_0035785...
# Downloading ISIC_0035784...
# Downloading ISIC_0035783...
# Downloading ISIC_0035782...
# Downloading ISIC_0035781...
# Downloading ISIC_0035780...
# Downloading ISIC_0035779...
# Downloading ISIC_0035778...
# Downloading ISIC_0035777...
# Downloading ISIC_0035776...
# Downloading ISIC_0035775...
# Downloading ISIC_0035774...
# Downloading ISIC_0035773...
# Downloading ISIC_0035772...
# Downloading ISIC_0035771...
# Downloading ISIC_0035770...
# Downloading ISIC_0035769...
# Downloading ISIC_0035768...
# Downloading ISIC_0035767...
# Downloading ISIC_0035766...
# Downloading ISIC_0035765...
# Downloading ISIC_0035764...
# Downloading ISIC_0035763...
# Downloading ISIC_0035762...
# Downloading ISIC_0035761...
# Downloading ISIC_0035760...
# Downloading ISIC_0035759...
# Downloading ISIC_0035758...
# Downloading ISIC_0035757...
# Downloading ISIC_0035756...
# Downloading ISIC_0035755...
# Downloading ISIC_0035754...
# Downloading ISIC_0035753...
# Downloading ISIC_0035752...
# Downloading ISIC_0035751...
# Downloading ISIC_0035750...
# Downloading ISIC_0035749...
# Downloading ISIC_0035748...
# Downloading ISIC_0035747...
# Downloading ISIC_0035746...
# Downloading ISIC_0035745...
# Downloading ISIC_0035744...
# Downloading ISIC_0035743...
# Downloading ISIC_0035742...
# Downloading ISIC_0035741...
# Downloading ISIC_0035740...
# Downloading ISIC_0035739...
# Downloading ISIC_0035738...
# Downloading ISIC_0035737...
# Downloading ISIC_0035736...
# Downloading ISIC_0035735...
# Downloading ISIC_0035734...
# Downloading ISIC_0035733...
# Downloading ISIC_0035732...
# Downloading ISIC_0035731...
# Downloading ISIC_0035730...
# Downloading ISIC_0035729...
# Downloading ISIC_0035728...
# Downloading ISIC_0035727...
# Downloading ISIC_0035726...
# Downloading ISIC_0035725...
# Downloading ISIC_0035724...
# Downloading ISIC_0035723...
# Downloading ISIC_0035722...
# Downloading ISIC_0035721...
# Downloading ISIC_0035720...
# Downloading ISIC_0035719...
# Downloading ISIC_0035718...
# Downloading ISIC_0035717...
# Downloading ISIC_0035716...
# Downloading ISIC_0035715...
# Downloading ISIC_0035714...
# Downloading ISIC_0035713...
# Downloading ISIC_0035712...
# Downloading ISIC_0035711...
# Downloading ISIC_0035710...
# Downloading ISIC_0035709...
# Downloading ISIC_0035708...
# Downloading ISIC_0035707...
# Downloading ISIC_0035706...
# Downloading ISIC_0035705...
# Downloading ISIC_0035704...
# Downloading ISIC_0035703...
# Downloading ISIC_0035702...
# Downloading ISIC_0035701...
# Downloading ISIC_0035700...
# Downloading ISIC_0035699...
# Downloading ISIC_0035698...
# Downloading ISIC_0035697...
# Downloading ISIC_0035696...
# Downloading ISIC_0035695...
# Downloading ISIC_0035694...
# Downloading ISIC_0035693...
# Downloading ISIC_0035692...
# Downloading ISIC_0035691...
# Downloading ISIC_0035690...
# Downloading ISIC_0035689...
# Downloading ISIC_0035688...
# Downloading ISIC_0035687...
# Downloading ISIC_0035686...
# Downloading ISIC_0035685...
# Downloading ISIC_0035684...
# Downloading ISIC_0035683...
# Downloading ISIC_0035682...
# Downloading ISIC_0035681...
# Downloading ISIC_0035680...
# Downloading ISIC_0035679...
# Downloading ISIC_0035678...
# Downloading ISIC_0035677...
# Downloading ISIC_0035676...
# Downloading ISIC_0035675...
# Downloading ISIC_0035674...
# Downloading ISIC_0035673...
# Downloading ISIC_0035672...
# Downloading ISIC_0035671...
# Downloading ISIC_0035670...
# Downloading ISIC_0035669...
# Downloading ISIC_0035668...
# Downloading ISIC_0035667...
# Downloading ISIC_0035666...
# Downloading ISIC_0035665...
# Downloading ISIC_0035664...
# Downloading ISIC_0035663...
# Downloading ISIC_0035662...
# Downloading ISIC_0035661...
# Downloading ISIC_0035660...
# Downloading ISIC_0035659...
# Downloading ISIC_0035658...
# Downloading ISIC_0035657...
# Downloading ISIC_0035656...
# Downloading ISIC_0035655...
# Downloading ISIC_0035654...
# Downloading ISIC_0035653...
# Downloading ISIC_0035652...
# Downloading ISIC_0035651...
# Downloading ISIC_0035650...
# Downloading ISIC_0035649...
# Downloading ISIC_0035648...
# Downloading ISIC_0035647...
# Downloading ISIC_0035646...
# Downloading ISIC_0035645...
# Downloading ISIC_0035644...
# Downloading ISIC_0035643...
# Downloading ISIC_0035642...
# Downloading ISIC_0035641...
# Downloading ISIC_0035640...
# Downloading ISIC_0035639...
# Downloading ISIC_0035638...
# Downloading ISIC_0035637...
# Downloading ISIC_0035636...
# Downloading ISIC_0035635...
# Downloading ISIC_0035634...
# Downloading ISIC_0035633...
# Downloading ISIC_0035632...
# Downloading ISIC_0035631...
# Downloading ISIC_0035630...
# Downloading ISIC_0035629...
# Downloading ISIC_0035628...
# Downloading ISIC_0035627...
# Downloading ISIC_0035626...
# Downloading ISIC_0035625...
# Downloading ISIC_0035624...
# Downloading ISIC_0035623...
# Downloading ISIC_0035622...
# Downloading ISIC_0035621...
# Downloading ISIC_0035619...
# Downloading ISIC_0035618...
# Downloading ISIC_0035617...
# Downloading ISIC_0035616...
# Downloading ISIC_0035615...
# Downloading ISIC_0035614...
# Downloading ISIC_0035613...
# Downloading ISIC_0035612...
# Downloading ISIC_0035611...
# Downloading ISIC_0035610...
# Downloading ISIC_0035609...
# Downloading ISIC_0035608...
# Downloading ISIC_0035607...
# Downloading ISIC_0035606...
# Downloading ISIC_0035605...
# Downloading ISIC_0035604...
# Downloading ISIC_0035603...
# Downloading ISIC_0035602...
# Downloading ISIC_0035601...
# Downloading ISIC_0035600...
# Downloading ISIC_0035599...
# Downloading ISIC_0035598...
# Downloading ISIC_0035597...
# Downloading ISIC_0035596...
# Downloading ISIC_0035594...
# Downloading ISIC_0035593...
# Downloading ISIC_0035592...
# Downloading ISIC_0035591...
# Downloading ISIC_0035590...
# Downloading ISIC_0035589...
# Downloading ISIC_0035588...
# Downloading ISIC_0035587...
# Downloading ISIC_0035586...
# Downloading ISIC_0035585...
# Downloading ISIC_0035584...
# Downloading ISIC_0035583...
# Downloading ISIC_0035582...
# Downloading ISIC_0035581...
# Downloading ISIC_0035580...
# Downloading ISIC_0035579...
# Downloading ISIC_0035578...
# Downloading ISIC_0035577...
# Downloading ISIC_0035576...
# Downloading ISIC_0035575...
# Downloading ISIC_0035574...
# Downloading ISIC_0035573...
# Downloading ISIC_0035572...
# Downloading ISIC_0035571...
# Downloading ISIC_0035570...
# Downloading ISIC_0035569...
# Downloading ISIC_0035568...
# Downloading ISIC_0035567...
# Downloading ISIC_0035566...
# Downloading ISIC_0035565...
# Downloading ISIC_0035564...
# Downloading ISIC_0035563...
# Downloading ISIC_0035562...
# Downloading ISIC_0035561...
# Downloading ISIC_0035560...
# Downloading ISIC_0035559...
# Downloading ISIC_0035558...
# Downloading ISIC_0035557...
# Downloading ISIC_0035556...
# Downloading ISIC_0035555...
# Downloading ISIC_0035554...
# Downloading ISIC_0035553...
# Downloading ISIC_0035552...
# Downloading ISIC_0035551...
# Downloading ISIC_0035550...
# Downloading ISIC_0035548...
# Downloading ISIC_0035547...
# Downloading ISIC_0035546...
# Downloading ISIC_0035545...
# Downloading ISIC_0035544...
# Downloading ISIC_0035543...
# Downloading ISIC_0035542...
# Downloading ISIC_0035541...
# Downloading ISIC_0035540...
# Downloading ISIC_0035539...
# Downloading ISIC_0035538...
# Downloading ISIC_0035537...
# Downloading ISIC_0035536...
# Downloading ISIC_0035535...
# Downloading ISIC_0035534...
# Downloading ISIC_0035533...
# Downloading ISIC_0035532...
# Downloading ISIC_0035531...
# Downloading ISIC_0035530...
# Downloading ISIC_0035529...
# Downloading ISIC_0035528...
# Downloading ISIC_0035527...
# Downloading ISIC_0035526...
# Downloading ISIC_0035525...
# Downloading ISIC_0035524...
# Downloading ISIC_0035523...
# Downloading ISIC_0035522...
# Downloading ISIC_0035521...
# Downloading ISIC_0035520...
# Downloading ISIC_0035519...
# Downloading ISIC_0035518...
# Downloading ISIC_0035517...
# Downloading ISIC_0035516...
# Downloading ISIC_0035515...
# Downloading ISIC_0035513...
# Downloading ISIC_0035512...
# Downloading ISIC_0035511...
# Downloading ISIC_0035510...
# Downloading ISIC_0035509...
# Downloading ISIC_0035508...
# Downloading ISIC_0035507...
# Downloading ISIC_0035506...
# Downloading ISIC_0035505...
# Downloading ISIC_0035504...
# Downloading ISIC_0035503...
# Downloading ISIC_0035501...
# Downloading ISIC_0035500...
# Downloading ISIC_0035499...
# Downloading ISIC_0035498...
# Downloading ISIC_0035497...
# Downloading ISIC_0035496...
# Downloading ISIC_0035495...
# Downloading ISIC_0035494...
# Downloading ISIC_0035493...
# Downloading ISIC_0035492...
# Downloading ISIC_0035491...
# Downloading ISIC_0035490...
# Downloading ISIC_0035489...
# Downloading ISIC_0035488...
# Downloading ISIC_0035487...
# Downloading ISIC_0035486...
# Downloading ISIC_0035485...
# Downloading ISIC_0035484...
# Downloading ISIC_0035483...
# Downloading ISIC_0035482...
# Downloading ISIC_0035481...
# Downloading ISIC_0035480...
# Downloading ISIC_0035479...
# Downloading ISIC_0035478...
# Downloading ISIC_0035477...
# Downloading ISIC_0035476...
# Downloading ISIC_0035475...
# Downloading ISIC_0035474...
# Downloading ISIC_0035473...
# Downloading ISIC_0035472...
# Downloading ISIC_0035471...
# Downloading ISIC_0035470...
# Downloading ISIC_0035469...
# Downloading ISIC_0035468...
# Downloading ISIC_0035467...
# Downloading ISIC_0035466...
# Downloading ISIC_0035465...
# Downloading ISIC_0035464...
# Downloading ISIC_0035463...
# Downloading ISIC_0035462...
# Downloading ISIC_0035461...
# Downloading ISIC_0035460...
# Downloading ISIC_0035459...
# Downloading ISIC_0035458...
# Downloading ISIC_0035457...
# Downloading ISIC_0035456...
# Downloading ISIC_0035455...
# Downloading ISIC_0035454...
# Downloading ISIC_0035453...
# Downloading ISIC_0035452...
# Downloading ISIC_0035451...
# Downloading ISIC_0035450...
# Downloading ISIC_0035449...
# Downloading ISIC_0035448...
# Downloading ISIC_0035447...
# Downloading ISIC_0035446...
# Downloading ISIC_0035445...
# Downloading ISIC_0035444...
# Downloading ISIC_0035443...
# Downloading ISIC_0035442...
# Downloading ISIC_0035441...
# Downloading ISIC_0035440...
# Downloading ISIC_0035439...
# Downloading ISIC_0035438...
# Downloading ISIC_0035437...
# Downloading ISIC_0035436...
# Downloading ISIC_0035435...
# Downloading ISIC_0035434...
# Downloading ISIC_0035433...
# Downloading ISIC_0035432...
# Downloading ISIC_0035431...
# Downloading ISIC_0035430...
# Downloading ISIC_0035429...
# Downloading ISIC_0035428...
# Downloading ISIC_0035427...
# Downloading ISIC_0035425...
# Downloading ISIC_0035423...
# Downloading ISIC_0035422...
# Downloading ISIC_0035421...
# Downloading ISIC_0035420...
# Downloading ISIC_0035419...
# Downloading ISIC_0035418...
# Downloading ISIC_0035417...
# Downloading ISIC_0035416...
# Downloading ISIC_0035415...
# Downloading ISIC_0035414...
# Downloading ISIC_0035413...
# Downloading ISIC_0035412...
# Downloading ISIC_0035411...
# Downloading ISIC_0035410...
# Downloading ISIC_0035409...
# Downloading ISIC_0035408...
# Downloading ISIC_0035407...
# Downloading ISIC_0035406...
# Downloading ISIC_0035405...
# Downloading ISIC_0035404...
# Downloading ISIC_0035403...
# Downloading ISIC_0035402...
# Downloading ISIC_0035401...
# Downloading ISIC_0035400...
# Downloading ISIC_0035399...
# Downloading ISIC_0035398...
# Downloading ISIC_0035397...
# Downloading ISIC_0035396...
# Downloading ISIC_0035395...
# Downloading ISIC_0035394...
# Downloading ISIC_0035393...
# Downloading ISIC_0035392...
# Downloading ISIC_0035391...
# Downloading ISIC_0035390...
# Downloading ISIC_0035389...
# Downloading ISIC_0035388...
# Downloading ISIC_0035387...
# Downloading ISIC_0035386...
# Downloading ISIC_0035385...
# Downloading ISIC_0035384...
# Downloading ISIC_0035383...
# Downloading ISIC_0035382...
# Downloading ISIC_0035381...
# Downloading ISIC_0035380...
# Downloading ISIC_0035379...
# Downloading ISIC_0035378...
# Downloading ISIC_0035377...
# Downloading ISIC_0035376...
# Downloading ISIC_0035375...
# Downloading ISIC_0035374...
# Downloading ISIC_0035373...
# Downloading ISIC_0035372...
# Downloading ISIC_0035370...
# Downloading ISIC_0035369...
# Downloading ISIC_0035368...
# Downloading ISIC_0035367...
# Downloading ISIC_0035366...
# Downloading ISIC_0035365...
# Downloading ISIC_0035364...
# Downloading ISIC_0035363...
# Downloading ISIC_0035362...
# Downloading ISIC_0035361...
# Downloading ISIC_0035360...
# Downloading ISIC_0035359...
# Downloading ISIC_0035358...
# Downloading ISIC_0035357...
# Downloading ISIC_0035356...
# Downloading ISIC_0035355...
# Downloading ISIC_0035354...
# Downloading ISIC_0035353...
# Downloading ISIC_0035352...
# Downloading ISIC_0035351...
# Downloading ISIC_0035350...
# Downloading ISIC_0035349...
# Downloading ISIC_0035348...
# Downloading ISIC_0035347...
# Downloading ISIC_0035346...
# Downloading ISIC_0035345...
# Downloading ISIC_0035344...
# Downloading ISIC_0035343...
# Downloading ISIC_0035342...
# Downloading ISIC_0035341...
# Downloading ISIC_0035340...
# Downloading ISIC_0035339...
# Downloading ISIC_0035338...
# Downloading ISIC_0035337...
# Downloading ISIC_0035336...
# Downloading ISIC_0035335...
# Downloading ISIC_0035334...
# Downloading ISIC_0035333...
# Downloading ISIC_0035332...
# Downloading ISIC_0035331...
# Downloading ISIC_0035330...
# Downloading ISIC_0035329...
# Downloading ISIC_0035328...
# Downloading ISIC_0035327...
# Downloading ISIC_0035326...
# Downloading ISIC_0035325...
# Downloading ISIC_0035324...
# Downloading ISIC_0035323...
# Downloading ISIC_0035322...
# Downloading ISIC_0035321...
# Downloading ISIC_0035320...
# Downloading ISIC_0035319...
# Downloading ISIC_0035318...
# Downloading ISIC_0035317...
# Downloading ISIC_0035316...
# Downloading ISIC_0035315...
# Downloading ISIC_0035314...
# Downloading ISIC_0035313...
# Downloading ISIC_0035312...
# Downloading ISIC_0035311...
# Downloading ISIC_0035310...
# Downloading ISIC_0035309...
# Downloading ISIC_0035308...
# Downloading ISIC_0035307...
# Downloading ISIC_0035306...
# Downloading ISIC_0035305...
# Downloading ISIC_0035304...
# Downloading ISIC_0035303...
# Downloading ISIC_0035302...
# Downloading ISIC_0035301...
# Downloading ISIC_0035300...
# Downloading ISIC_0035299...
# Downloading ISIC_0035298...
# Downloading ISIC_0035297...
# Downloading ISIC_0035296...
# Downloading ISIC_0035295...
# Downloading ISIC_0035294...
# Downloading ISIC_0035293...
# Downloading ISIC_0035292...
# Downloading ISIC_0035291...
# Downloading ISIC_0035290...
# Downloading ISIC_0035289...
# Downloading ISIC_0035288...
# Downloading ISIC_0035287...
# Downloading ISIC_0035286...
# Downloading ISIC_0035285...
# Downloading ISIC_0035284...
# Downloading ISIC_0035283...
# Downloading ISIC_0035282...
# Downloading ISIC_0035281...
# Downloading ISIC_0035280...
# Downloading ISIC_0035278...
# Downloading ISIC_0035277...
# Downloading ISIC_0035276...
# Downloading ISIC_0035275...
# Downloading ISIC_0035274...
# Downloading ISIC_0035273...
# Downloading ISIC_0035272...
# Downloading ISIC_0035271...
# Downloading ISIC_0035270...
# Downloading ISIC_0035268...
# Downloading ISIC_0035267...
# Downloading ISIC_0035266...
# Downloading ISIC_0035265...
# Downloading ISIC_0035264...
# Downloading ISIC_0035263...
# Downloading ISIC_0035262...
# Downloading ISIC_0035261...
# Downloading ISIC_0035260...
# Downloading ISIC_0035259...
# Downloading ISIC_0035258...
# Downloading ISIC_0035257...
# Downloading ISIC_0035256...
# Downloading ISIC_0035255...
# Downloading ISIC_0035254...
# Downloading ISIC_0035253...
# Downloading ISIC_0035250...
# Downloading ISIC_0035248...
# Downloading ISIC_0035247...
# Downloading ISIC_0035246...
# Downloading ISIC_0035245...
# Downloading ISIC_0035244...
# Downloading ISIC_0035243...
# Downloading ISIC_0035242...
# Downloading ISIC_0035241...
# Downloading ISIC_0035240...
# Downloading ISIC_0035239...
# Downloading ISIC_0035238...
# Downloading ISIC_0035237...
# Downloading ISIC_0035236...
# Downloading ISIC_0035235...
# Downloading ISIC_0035234...
# Downloading ISIC_0035233...
# Downloading ISIC_0035232...
# Downloading ISIC_0035231...
# Downloading ISIC_0035230...
# Downloading ISIC_0035229...
# Downloading ISIC_0035228...
# Downloading ISIC_0035227...
# Downloading ISIC_0035226...
# Downloading ISIC_0035225...
# Downloading ISIC_0035224...
# Downloading ISIC_0035223...
# Downloading ISIC_0035222...
# Downloading ISIC_0035221...
# Downloading ISIC_0035220...
# Downloading ISIC_0035219...
# Downloading ISIC_0035218...
# Downloading ISIC_0035217...
# Downloading ISIC_0035216...
# Downloading ISIC_0035215...
# Downloading ISIC_0035214...
# Downloading ISIC_0035213...
# Downloading ISIC_0035212...
# Downloading ISIC_0035211...
# Downloading ISIC_0035210...
# Downloading ISIC_0035209...
# Downloading ISIC_0035208...
# Downloading ISIC_0035207...
# Downloading ISIC_0035206...
# Downloading ISIC_0035205...
# Downloading ISIC_0035204...
# Downloading ISIC_0035202...
# Downloading ISIC_0035201...
# Downloading ISIC_0035200...
# Downloading ISIC_0035199...
# Downloading ISIC_0035198...
# Downloading ISIC_0035197...
# Downloading ISIC_0035196...
# Downloading ISIC_0035195...
# Downloading ISIC_0035194...
# Downloading ISIC_0035193...
# Downloading ISIC_0035192...
# Downloading ISIC_0035191...
# Downloading ISIC_0035190...
# Downloading ISIC_0035189...
# Downloading ISIC_0035188...
# Downloading ISIC_0035187...
# Downloading ISIC_0035186...
# Downloading ISIC_0035185...
# Downloading ISIC_0035184...
# Downloading ISIC_0035182...
# Downloading ISIC_0035181...
# Downloading ISIC_0035180...
# Downloading ISIC_0035179...
# Downloading ISIC_0035178...
# Downloading ISIC_0035177...
# Downloading ISIC_0035176...
# Downloading ISIC_0035175...
# Downloading ISIC_0035173...
# Downloading ISIC_0035172...
# Downloading ISIC_0035171...
# Downloading ISIC_0035170...
# Downloading ISIC_0035169...
# Downloading ISIC_0035168...
# Downloading ISIC_0035167...
# Downloading ISIC_0035166...
# Downloading ISIC_0035165...
# Downloading ISIC_0035164...
# Downloading ISIC_0035163...
# Downloading ISIC_0035162...
# Downloading ISIC_0035161...
# Downloading ISIC_0035160...
# Downloading ISIC_0035158...
# Downloading ISIC_0035157...
# Downloading ISIC_0035156...
# Downloading ISIC_0035155...
# Downloading ISIC_0035154...
# Downloading ISIC_0035153...
# Downloading ISIC_0035152...
# Downloading ISIC_0035151...
# Downloading ISIC_0035150...
# Downloading ISIC_0035149...
# Downloading ISIC_0035148...
# Downloading ISIC_0035147...
# Downloading ISIC_0035146...
# Downloading ISIC_0035145...
# Downloading ISIC_0035144...
# Downloading ISIC_0035143...
# Downloading ISIC_0035142...
# Downloading ISIC_0035140...
# Downloading ISIC_0035139...
# Downloading ISIC_0035138...
# Downloading ISIC_0035137...
# Downloading ISIC_0035136...
# Downloading ISIC_0035135...
# Downloading ISIC_0035134...
# Downloading ISIC_0035133...
# Downloading ISIC_0035132...
# Downloading ISIC_0035131...
# Downloading ISIC_0035130...
# Downloading ISIC_0035129...
# Downloading ISIC_0035128...
# Downloading ISIC_0035127...
# Downloading ISIC_0035126...
# Downloading ISIC_0035125...
# Downloading ISIC_0035124...
# Downloading ISIC_0035123...
# Downloading ISIC_0035122...
# Downloading ISIC_0035121...
# Downloading ISIC_0035120...
# Downloading ISIC_0035119...
# Downloading ISIC_0035118...
# Downloading ISIC_0035117...
# Downloading ISIC_0035116...
# Downloading ISIC_0035115...
# Downloading ISIC_0035114...
# Downloading ISIC_0035113...
# Downloading ISIC_0035112...
# Downloading ISIC_0035111...
# Downloading ISIC_0035110...
# Downloading ISIC_0035109...
# Downloading ISIC_0035108...
# Downloading ISIC_0035107...
# Downloading ISIC_0035106...
# Downloading ISIC_0035105...
# Downloading ISIC_0035104...
# Downloading ISIC_0035103...
# Downloading ISIC_0035102...
# Downloading ISIC_0035101...
# Downloading ISIC_0035100...
# Downloading ISIC_0035099...
# Downloading ISIC_0035098...
# Downloading ISIC_0035097...
# Downloading ISIC_0035096...
# Downloading ISIC_0035095...
# Downloading ISIC_0035094...
# Downloading ISIC_0035093...
# Downloading ISIC_0035092...
# Downloading ISIC_0035091...
# Downloading ISIC_0035090...
# Downloading ISIC_0035089...
# Downloading ISIC_0035088...
# Downloading ISIC_0035087...
# Downloading ISIC_0035086...
# Downloading ISIC_0035085...
# Downloading ISIC_0035084...
# Downloading ISIC_0035083...
# Downloading ISIC_0035082...
# Downloading ISIC_0035081...
# Downloading ISIC_0035080...
# Downloading ISIC_0035079...
# Downloading ISIC_0035078...
# Downloading ISIC_0035077...
# Downloading ISIC_0035076...
# Downloading ISIC_0035075...
# Downloading ISIC_0035074...
# Downloading ISIC_0035073...
# Downloading ISIC_0035072...
# Downloading ISIC_0035071...
# Downloading ISIC_0035070...
# Downloading ISIC_0035068...
# Downloading ISIC_0035067...
# Downloading ISIC_0035066...
# Downloading ISIC_0035065...
# Downloading ISIC_0035064...
# Downloading ISIC_0035063...
# Downloading ISIC_0035062...
# Downloading ISIC_0035061...
# Downloading ISIC_0035060...
# Downloading ISIC_0035059...
# Downloading ISIC_0035058...
# Downloading ISIC_0035057...
# Downloading ISIC_0035056...
# Downloading ISIC_0035055...
# Downloading ISIC_0035054...
# Downloading ISIC_0035053...
# Downloading ISIC_0035052...
# Downloading ISIC_0035051...
# Downloading ISIC_0035050...
# Downloading ISIC_0035049...
# Downloading ISIC_0035048...
# Downloading ISIC_0035047...
# Downloading ISIC_0035046...
# Downloading ISIC_0035045...
# Downloading ISIC_0035044...
# Downloading ISIC_0035043...
# Downloading ISIC_0035042...
# Downloading ISIC_0035041...
# Downloading ISIC_0035040...
# Downloading ISIC_0035039...
# Downloading ISIC_0035038...
# Downloading ISIC_0035037...
# Downloading ISIC_0035036...
# Downloading ISIC_0035035...
# Downloading ISIC_0035034...
# Downloading ISIC_0035033...
# Downloading ISIC_0035032...
# Downloading ISIC_0035031...
# Downloading ISIC_0035030...
# Downloading ISIC_0035029...
# Downloading ISIC_0035028...
# Downloading ISIC_0035027...
# Downloading ISIC_0035026...
# Downloading ISIC_0035025...
# Downloading ISIC_0035024...
# Downloading ISIC_0035023...
# Downloading ISIC_0035022...
# Downloading ISIC_0035021...
# Downloading ISIC_0035020...
# Downloading ISIC_0035019...
# Downloading ISIC_0035018...
# Downloading ISIC_0035017...
# Downloading ISIC_0035016...
# Downloading ISIC_0035015...
# Downloading ISIC_0035014...
# Downloading ISIC_0035013...
# Downloading ISIC_0035012...
# Downloading ISIC_0035011...
# Downloading ISIC_0035010...
# Downloading ISIC_0035009...
# Downloading ISIC_0035008...
# Downloading ISIC_0035007...
# Downloading ISIC_0035006...
# Downloading ISIC_0035005...
# Downloading ISIC_0035004...
# Downloading ISIC_0035003...
# Downloading ISIC_0035002...
# Downloading ISIC_0035001...
# Downloading ISIC_0035000...
# Downloading ISIC_0034999...
# Downloading ISIC_0034998...
# Downloading ISIC_0034997...
# Downloading ISIC_0034996...
# Downloading ISIC_0034995...
# Downloading ISIC_0034994...
# Downloading ISIC_0034993...
# Downloading ISIC_0034992...
# Downloading ISIC_0034991...
# Downloading ISIC_0034990...
# Downloading ISIC_0034989...
# Downloading ISIC_0034988...
# Downloading ISIC_0034987...
# Downloading ISIC_0034986...
# Downloading ISIC_0034985...
# Downloading ISIC_0034984...
# Downloading ISIC_0034983...
# Downloading ISIC_0034982...
# Downloading ISIC_0034980...
# Downloading ISIC_0034979...
# Downloading ISIC_0034978...
# Downloading ISIC_0034977...
# Downloading ISIC_0034976...
# Downloading ISIC_0034975...
# Downloading ISIC_0034974...
# Downloading ISIC_0034973...
# Downloading ISIC_0034972...
# Downloading ISIC_0034971...
# Downloading ISIC_0034970...
# Downloading ISIC_0034968...
# Downloading ISIC_0034967...
# Downloading ISIC_0034966...
# Downloading ISIC_0034965...
# Downloading ISIC_0034964...
# Downloading ISIC_0034962...
# Downloading ISIC_0034961...
# Downloading ISIC_0034960...
# Downloading ISIC_0034959...
# Downloading ISIC_0034958...
# Downloading ISIC_0034957...
# Downloading ISIC_0034956...
# Downloading ISIC_0034955...
# Downloading ISIC_0034954...
# Downloading ISIC_0034953...
# Downloading ISIC_0034952...
# Downloading ISIC_0034951...
# Downloading ISIC_0034950...
# Downloading ISIC_0034949...
# Downloading ISIC_0034948...
# Downloading ISIC_0034947...
# Downloading ISIC_0034946...
# Downloading ISIC_0034945...
# Downloading ISIC_0034944...
# Downloading ISIC_0034943...
# Downloading ISIC_0034942...
# Downloading ISIC_0034941...
# Downloading ISIC_0034940...
# Downloading ISIC_0034939...
# Downloading ISIC_0034938...
# Downloading ISIC_0034937...
# Downloading ISIC_0034936...
# Downloading ISIC_0034935...
# Downloading ISIC_0034934...
# Downloading ISIC_0034933...
# Downloading ISIC_0034932...
# Downloading ISIC_0034931...
# Downloading ISIC_0034930...
# Downloading ISIC_0034928...
# Downloading ISIC_0034927...
# Downloading ISIC_0034926...
# Downloading ISIC_0034925...
# Downloading ISIC_0034924...
# Downloading ISIC_0034923...
# Downloading ISIC_0034922...
# Downloading ISIC_0034921...
# Downloading ISIC_0034920...
# Downloading ISIC_0034919...
# Downloading ISIC_0034918...
# Downloading ISIC_0034917...
# Downloading ISIC_0034916...
# Downloading ISIC_0034915...
# Downloading ISIC_0034914...
# Downloading ISIC_0034913...
# Downloading ISIC_0034912...
# Downloading ISIC_0034911...
# Downloading ISIC_0034910...
# Downloading ISIC_0034909...
# Downloading ISIC_0034908...
# Downloading ISIC_0034907...
# Downloading ISIC_0034906...
# Downloading ISIC_0034905...
# Downloading ISIC_0034904...
# Downloading ISIC_0034903...
# Downloading ISIC_0034902...
# Downloading ISIC_0034901...
# Downloading ISIC_0034900...
# Downloading ISIC_0034899...
# Downloading ISIC_0034898...
# Downloading ISIC_0034897...
# Downloading ISIC_0034896...
# Downloading ISIC_0034895...
# Downloading ISIC_0034894...
# Downloading ISIC_0034893...
# Downloading ISIC_0034892...
# Downloading ISIC_0034891...
# Downloading ISIC_0034890...
# Downloading ISIC_0034889...
# Downloading ISIC_0034888...
# Downloading ISIC_0034887...
# Downloading ISIC_0034886...
# Downloading ISIC_0034885...
# Downloading ISIC_0034884...
# Downloading ISIC_0034883...
# Downloading ISIC_0034882...
# Downloading ISIC_0034881...
# Downloading ISIC_0034880...
# Downloading ISIC_0034879...
# Downloading ISIC_0034878...
# Downloading ISIC_0034877...
# Downloading ISIC_0034876...
# Downloading ISIC_0034875...
# Downloading ISIC_0034874...
# Downloading ISIC_0034873...
# Downloading ISIC_0034872...
# Downloading ISIC_0034871...
# Downloading ISIC_0034870...
# Downloading ISIC_0034869...
# Downloading ISIC_0034868...
# Downloading ISIC_0034867...
# Downloading ISIC_0034866...
# Downloading ISIC_0034865...
# Downloading ISIC_0034864...
# Downloading ISIC_0034863...
# Downloading ISIC_0034862...
# Downloading ISIC_0034861...
# Downloading ISIC_0034860...
# Downloading ISIC_0034859...
# Downloading ISIC_0034858...
# Downloading ISIC_0034857...
# Downloading ISIC_0034856...
# Downloading ISIC_0034855...
# Downloading ISIC_0034854...
# Downloading ISIC_0034853...
# Downloading ISIC_0034852...
# Downloading ISIC_0034851...
# Downloading ISIC_0034850...
# Downloading ISIC_0034849...
# Downloading ISIC_0034848...
# Downloading ISIC_0034847...
# Downloading ISIC_0034846...
# Downloading ISIC_0034845...
# Downloading ISIC_0034844...
# Downloading ISIC_0034843...
# Downloading ISIC_0034842...
# Downloading ISIC_0034841...
# Downloading ISIC_0034840...
# Downloading ISIC_0034839...
# Downloading ISIC_0034838...
# Downloading ISIC_0034837...
# Downloading ISIC_0034836...
# Downloading ISIC_0034835...
# Downloading ISIC_0034834...
# Downloading ISIC_0034833...
# Downloading ISIC_0034832...
# Downloading ISIC_0034831...
# Downloading ISIC_0034830...
# Downloading ISIC_0034829...
# Downloading ISIC_0034828...
# Downloading ISIC_0034827...
# Downloading ISIC_0034826...
# Downloading ISIC_0034825...
# Downloading ISIC_0034824...
# Downloading ISIC_0034823...
# Downloading ISIC_0034822...
# Downloading ISIC_0034821...
# Downloading ISIC_0034820...
# Downloading ISIC_0034819...
# Downloading ISIC_0034818...
# Downloading ISIC_0034817...
# Downloading ISIC_0034816...
# Downloading ISIC_0034815...
# Downloading ISIC_0034814...
# Downloading ISIC_0034813...
# Downloading ISIC_0034812...
# Downloading ISIC_0034811...
# Downloading ISIC_0034810...
# Downloading ISIC_0034809...
# Downloading ISIC_0034808...
# Downloading ISIC_0034807...
# Downloading ISIC_0034806...
# Downloading ISIC_0034805...
# Downloading ISIC_0034804...
# Downloading ISIC_0034803...
# Downloading ISIC_0034802...
# Downloading ISIC_0034801...
# Downloading ISIC_0034800...
# Downloading ISIC_0034798...
# Downloading ISIC_0034797...
# Downloading ISIC_0034795...
# Downloading ISIC_0034794...
# Downloading ISIC_0034793...
# Downloading ISIC_0034792...
# Downloading ISIC_0034791...
# Downloading ISIC_0034790...
# Downloading ISIC_0034789...
# Downloading ISIC_0034788...
# Downloading ISIC_0034787...
# Downloading ISIC_0034786...
# Downloading ISIC_0034785...
# Downloading ISIC_0034784...
# Downloading ISIC_0034783...
# Downloading ISIC_0034782...
# Downloading ISIC_0034781...
# Downloading ISIC_0034780...
# Downloading ISIC_0034779...
# Downloading ISIC_0034778...
# Downloading ISIC_0034777...
# Downloading ISIC_0034776...
# Downloading ISIC_0034774...
# Downloading ISIC_0034773...
# Downloading ISIC_0034772...
# Downloading ISIC_0034771...
# Downloading ISIC_0034770...
# Downloading ISIC_0034769...
# Downloading ISIC_0034768...
# Downloading ISIC_0034767...
# Downloading ISIC_0034766...
# Downloading ISIC_0034765...
# Downloading ISIC_0034764...
# Downloading ISIC_0034763...
# Downloading ISIC_0034762...
# Downloading ISIC_0034761...
# Downloading ISIC_0034760...
# Downloading ISIC_0034759...
# Downloading ISIC_0034758...
# Downloading ISIC_0034757...
# Downloading ISIC_0034756...
# Downloading ISIC_0034755...
# Downloading ISIC_0034754...
# Downloading ISIC_0034753...
# Downloading ISIC_0034752...
# Downloading ISIC_0034751...
# Downloading ISIC_0034750...
# Downloading ISIC_0034749...
# Downloading ISIC_0034748...
# Downloading ISIC_0034747...
# Downloading ISIC_0034746...
# Downloading ISIC_0034745...
# Downloading ISIC_0034744...
# Downloading ISIC_0034743...
# Downloading ISIC_0034742...
# Downloading ISIC_0034741...
# Downloading ISIC_0034740...
# Downloading ISIC_0034739...
# Downloading ISIC_0034738...
# Downloading ISIC_0034737...
# Downloading ISIC_0034736...
# Downloading ISIC_0034735...
# Downloading ISIC_0034734...
# Downloading ISIC_0034733...
# Downloading ISIC_0034732...
# Downloading ISIC_0034731...
# Downloading ISIC_0034730...
# Downloading ISIC_0034729...
# Downloading ISIC_0034728...
# Downloading ISIC_0034727...
# Downloading ISIC_0034726...
# Downloading ISIC_0034725...
# Downloading ISIC_0034724...
# Downloading ISIC_0034723...
# Downloading ISIC_0034722...
# Downloading ISIC_0034721...
# Downloading ISIC_0034720...
# Downloading ISIC_0034719...
# Downloading ISIC_0034718...
# Downloading ISIC_0034717...
# Downloading ISIC_0034716...
# Downloading ISIC_0034715...
# Downloading ISIC_0034714...
# Downloading ISIC_0034713...
# Downloading ISIC_0034712...
# Downloading ISIC_0034711...
# Downloading ISIC_0034710...
# Downloading ISIC_0034709...
# Downloading ISIC_0034708...
# Downloading ISIC_0034707...
# Downloading ISIC_0034706...
# Downloading ISIC_0034705...
# Downloading ISIC_0034704...
# Downloading ISIC_0034703...
# Downloading ISIC_0034702...
# Downloading ISIC_0034701...
# Downloading ISIC_0034700...
# Downloading ISIC_0034699...
# Downloading ISIC_0034698...
# Downloading ISIC_0034697...
# Downloading ISIC_0034696...
# Downloading ISIC_0034695...
# Downloading ISIC_0034694...
# Downloading ISIC_0034693...
# Downloading ISIC_0034692...
# Downloading ISIC_0034691...
# Downloading ISIC_0034690...
# Downloading ISIC_0034689...
# Downloading ISIC_0034688...
# Downloading ISIC_0034687...
# Downloading ISIC_0034686...
# Downloading ISIC_0034685...
# Downloading ISIC_0034684...
# Downloading ISIC_0034683...
# Downloading ISIC_0034682...
# Downloading ISIC_0034681...
# Downloading ISIC_0034680...
# Downloading ISIC_0034679...
# Downloading ISIC_0034678...
# Downloading ISIC_0034677...
# Downloading ISIC_0034676...
# Downloading ISIC_0034675...
# Downloading ISIC_0034674...
# Downloading ISIC_0034672...
# Downloading ISIC_0034671...
# Downloading ISIC_0034670...
# Downloading ISIC_0034669...
# Downloading ISIC_0034668...
# Downloading ISIC_0034667...
# Downloading ISIC_0034666...
# Downloading ISIC_0034665...
# Downloading ISIC_0034664...
# Downloading ISIC_0034663...
# Downloading ISIC_0034662...
# Downloading ISIC_0034661...
# Downloading ISIC_0034660...
# Downloading ISIC_0034659...
# Downloading ISIC_0034658...
# Downloading ISIC_0034657...
# Downloading ISIC_0034656...
# Downloading ISIC_0034655...
# Downloading ISIC_0034654...
# Downloading ISIC_0034653...
# Downloading ISIC_0034652...
# Downloading ISIC_0034651...
# Downloading ISIC_0034650...
# Downloading ISIC_0034649...
# Downloading ISIC_0034648...
# Downloading ISIC_0034646...
# Downloading ISIC_0034645...
# Downloading ISIC_0034644...
# Downloading ISIC_0034643...
# Downloading ISIC_0034642...
# Downloading ISIC_0034641...
# Downloading ISIC_0034640...
# Downloading ISIC_0034639...
# Downloading ISIC_0034638...
# Downloading ISIC_0034637...
# Downloading ISIC_0034636...
# Downloading ISIC_0034635...
# Downloading ISIC_0034634...
# Downloading ISIC_0034633...
# Downloading ISIC_0034632...
# Downloading ISIC_0034631...
# Downloading ISIC_0034630...
# Downloading ISIC_0034629...
# Downloading ISIC_0034628...
# Downloading ISIC_0034627...
# Downloading ISIC_0034626...
# Downloading ISIC_0034625...
# Downloading ISIC_0034624...
# Downloading ISIC_0034623...
# Downloading ISIC_0034622...
# Downloading ISIC_0034621...
# Downloading ISIC_0034620...
# Downloading ISIC_0034619...
# Downloading ISIC_0034618...
# Downloading ISIC_0034617...
# Downloading ISIC_0034616...
# Downloading ISIC_0034615...
# Downloading ISIC_0034614...
# Downloading ISIC_0034613...
# Downloading ISIC_0034612...
# Downloading ISIC_0034611...
# Downloading ISIC_0034610...
# Downloading ISIC_0034609...
# Downloading ISIC_0034608...
# Downloading ISIC_0034607...
# Downloading ISIC_0034606...
# Downloading ISIC_0034605...
# Downloading ISIC_0034604...
# Downloading ISIC_0034603...
# Downloading ISIC_0034602...
# Downloading ISIC_0034601...
# Downloading ISIC_0034600...
# Downloading ISIC_0034599...
# Downloading ISIC_0034598...
# Downloading ISIC_0034597...
# Downloading ISIC_0034596...
# Downloading ISIC_0034595...
# Downloading ISIC_0034594...
# Downloading ISIC_0034593...
# Downloading ISIC_0034592...
# Downloading ISIC_0034591...
# Downloading ISIC_0034590...
# Downloading ISIC_0034589...
# Downloading ISIC_0034588...
# Downloading ISIC_0034587...
# Downloading ISIC_0034586...
# Downloading ISIC_0034585...
# Downloading ISIC_0034584...
# Downloading ISIC_0034583...
# Downloading ISIC_0034582...
# Downloading ISIC_0034581...
# Downloading ISIC_0034580...
# Downloading ISIC_0034579...
# Downloading ISIC_0034578...
# Downloading ISIC_0034577...
# Downloading ISIC_0034576...
# Downloading ISIC_0034575...
# Downloading ISIC_0034574...
# Downloading ISIC_0034573...
# Downloading ISIC_0034572...
# Downloading ISIC_0034571...
# Downloading ISIC_0034570...
# Downloading ISIC_0034569...
# Downloading ISIC_0034568...
# Downloading ISIC_0034567...
# Downloading ISIC_0034566...
# Downloading ISIC_0034565...
# Downloading ISIC_0034564...
# Downloading ISIC_0034563...
# Downloading ISIC_0034562...
# Downloading ISIC_0034561...
# Downloading ISIC_0034560...
# Downloading ISIC_0034559...
# Downloading ISIC_0034558...
# Downloading ISIC_0034557...
# Downloading ISIC_0034556...
# Downloading ISIC_0034555...
# Downloading ISIC_0034554...
# Downloading ISIC_0034553...
# Downloading ISIC_0034552...
# Downloading ISIC_0034551...
# Downloading ISIC_0034549...
# Downloading ISIC_0034548...
# Downloading ISIC_0034547...
# Downloading ISIC_0034546...
# Downloading ISIC_0034545...
# Downloading ISIC_0034544...
# Downloading ISIC_0034543...
# Downloading ISIC_0034542...
# Downloading ISIC_0034541...
# Downloading ISIC_0034540...
# Downloading ISIC_0034539...
# Downloading ISIC_0034538...
# Downloading ISIC_0034537...
# Downloading ISIC_0034536...
# Downloading ISIC_0034535...
# Downloading ISIC_0034534...
# Downloading ISIC_0034533...
# Downloading ISIC_0034532...
# Downloading ISIC_0034531...
# Downloading ISIC_0034530...
# Downloading ISIC_0034529...
# Downloading ISIC_0034528...
# Downloading ISIC_0034527...
# Downloading ISIC_0034526...
# Downloading ISIC_0034525...
# Downloading ISIC_0034524...
# Downloading ISIC_0034523...
# Downloading ISIC_0034522...
# Downloading ISIC_0034521...
# Downloading ISIC_0034520...
# Downloading ISIC_0034519...
# Downloading ISIC_0034518...
# Downloading ISIC_0034517...
# Downloading ISIC_0034516...
# Downloading ISIC_0034515...
# Downloading ISIC_0034514...
# Downloading ISIC_0034513...
# Downloading ISIC_0034512...
# Downloading ISIC_0034511...
# Downloading ISIC_0034510...
# Downloading ISIC_0034509...
# Downloading ISIC_0034508...
# Downloading ISIC_0034507...
# Downloading ISIC_0034506...
# Downloading ISIC_0034505...
# Downloading ISIC_0034504...
# Downloading ISIC_0034503...
# Downloading ISIC_0034502...
# Downloading ISIC_0034501...
# Downloading ISIC_0034500...
# Downloading ISIC_0034499...
# Downloading ISIC_0034498...
# Downloading ISIC_0034497...
# Downloading ISIC_0034496...
# Downloading ISIC_0034495...
# Downloading ISIC_0034494...
# Downloading ISIC_0034493...
# Downloading ISIC_0034492...
# Downloading ISIC_0034491...
# Downloading ISIC_0034490...
# Downloading ISIC_0034489...
# Downloading ISIC_0034488...
# Downloading ISIC_0034487...
# Downloading ISIC_0034486...
# Downloading ISIC_0034485...
# Downloading ISIC_0034484...
# Downloading ISIC_0034483...
# Downloading ISIC_0034482...
# Downloading ISIC_0034481...
# Downloading ISIC_0034480...
# Downloading ISIC_0034478...
# Downloading ISIC_0034477...
# Downloading ISIC_0034476...
# Downloading ISIC_0034475...
# Downloading ISIC_0034474...
# Downloading ISIC_0034472...
# Downloading ISIC_0034471...
# Downloading ISIC_0034470...
# Downloading ISIC_0034469...
# Downloading ISIC_0034468...
# Downloading ISIC_0034467...
# Downloading ISIC_0034466...
# Downloading ISIC_0034465...
# Downloading ISIC_0034464...
# Downloading ISIC_0034463...
# Downloading ISIC_0034461...
# Downloading ISIC_0034460...
# Downloading ISIC_0034459...
# Downloading ISIC_0034458...
# Downloading ISIC_0034457...
# Downloading ISIC_0034456...
# Downloading ISIC_0034455...
# Downloading ISIC_0034454...
# Downloading ISIC_0034453...
# Downloading ISIC_0034452...
# Downloading ISIC_0034451...
# Downloading ISIC_0034450...
# Downloading ISIC_0034449...
# Downloading ISIC_0034448...
# Downloading ISIC_0034447...
# Downloading ISIC_0034446...
# Downloading ISIC_0034445...
# Downloading ISIC_0034444...
# Downloading ISIC_0034443...
# Downloading ISIC_0034442...
# Downloading ISIC_0034441...
# Downloading ISIC_0034440...
# Downloading ISIC_0034439...
# Downloading ISIC_0034438...
# Downloading ISIC_0034437...
# Downloading ISIC_0034436...
# Downloading ISIC_0034435...
# Downloading ISIC_0034434...
# Downloading ISIC_0034433...
# Downloading ISIC_0034431...
# Downloading ISIC_0034430...
# Downloading ISIC_0034429...
# Downloading ISIC_0034428...
# Downloading ISIC_0034427...
# Downloading ISIC_0034426...
# Downloading ISIC_0034425...
# Downloading ISIC_0034424...
# Downloading ISIC_0034423...
# Downloading ISIC_0034422...
# Downloading ISIC_0034421...
# Downloading ISIC_0034420...
# Downloading ISIC_0034419...
# Downloading ISIC_0034418...
# Downloading ISIC_0034417...
# Downloading ISIC_0034416...
# Downloading ISIC_0034415...
# Downloading ISIC_0034414...
# Downloading ISIC_0034413...
# Downloading ISIC_0034412...
# Downloading ISIC_0034411...
# Downloading ISIC_0034410...
# Downloading ISIC_0034409...
# Downloading ISIC_0034408...
# Downloading ISIC_0034407...
# Downloading ISIC_0034406...
# Downloading ISIC_0034405...
# Downloading ISIC_0034404...
# Downloading ISIC_0034403...
# Downloading ISIC_0034402...
# Downloading ISIC_0034401...
# Downloading ISIC_0034400...
# Downloading ISIC_0034399...
# Downloading ISIC_0034398...
# Downloading ISIC_0034397...
# Downloading ISIC_0034396...
# Downloading ISIC_0034395...
# Downloading ISIC_0034394...
# Downloading ISIC_0034393...
# Downloading ISIC_0034392...
# Downloading ISIC_0034391...
# Downloading ISIC_0034390...
# Downloading ISIC_0034389...
# Downloading ISIC_0034387...
# Downloading ISIC_0034386...
# Downloading ISIC_0034385...
# Downloading ISIC_0034383...
# Downloading ISIC_0034382...
# Downloading ISIC_0034381...
# Downloading ISIC_0034380...
# Downloading ISIC_0034379...
# Downloading ISIC_0034378...
# Downloading ISIC_0034377...
# Downloading ISIC_0034376...
# Downloading ISIC_0034375...
# Downloading ISIC_0034374...
# Downloading ISIC_0034372...
# Downloading ISIC_0034371...
# Downloading ISIC_0034370...
# Downloading ISIC_0034369...
# Downloading ISIC_0034368...
# Downloading ISIC_0034367...
# Downloading ISIC_0034366...
# Downloading ISIC_0034365...
# Downloading ISIC_0034364...
# Downloading ISIC_0034363...
# Downloading ISIC_0034362...
# Downloading ISIC_0034361...
# Downloading ISIC_0034360...
# Downloading ISIC_0034359...
# Downloading ISIC_0034357...
# Downloading ISIC_0034356...
# Downloading ISIC_0034355...
# Downloading ISIC_0034354...
# Downloading ISIC_0034352...
# Downloading ISIC_0034351...
# Downloading ISIC_0034350...
# Downloading ISIC_0034349...
# Downloading ISIC_0034348...
# Downloading ISIC_0034347...
# Downloading ISIC_0034346...
# Downloading ISIC_0034345...
# Downloading ISIC_0034344...
# Downloading ISIC_0034343...
# Downloading ISIC_0034342...
# Downloading ISIC_0034341...
# Downloading ISIC_0034340...
# Downloading ISIC_0034339...
# Downloading ISIC_0034338...
# Downloading ISIC_0034337...
# Downloading ISIC_0034336...
# Downloading ISIC_0034335...
# Downloading ISIC_0034334...
# Downloading ISIC_0034333...
# Downloading ISIC_0034332...
# Downloading ISIC_0034331...
# Downloading ISIC_0034330...
# Downloading ISIC_0034329...
# Downloading ISIC_0034328...
# Downloading ISIC_0034326...
# Downloading ISIC_0034325...
# Downloading ISIC_0034324...
# Downloading ISIC_0034323...
# Downloading ISIC_0034322...
# Downloading ISIC_0034321...
# Downloading ISIC_0034320...
# Downloading ISIC_0034319...
# Downloading ISIC_0034318...
# Downloading ISIC_0034317...
# Downloading ISIC_0034316...
# Downloading ISIC_0034315...
# Downloading ISIC_0034314...
# Downloading ISIC_0034313...
# Downloading ISIC_0034312...
# ...
# Downloading ISIC_0032892...
# Downloading ISIC_0032891...
# Downloading ISIC_0032890...
# Downloading ISIC_0032889...
# Downloading ISIC_0032888...
# Downloading ISIC_0032887...
# Downloading ISIC_0032886...
# Downloading ISIC_0032885...
# Downloading ISIC_0032884...
# Downloading ISIC_0032883...
# Downloading ISIC_0032882...
# Downloading ISIC_0032881...
# Downloading ISIC_0032880...
# Downloading ISIC_0032879...
# Downloading ISIC_0032878...
# Downloading ISIC_0032877...
# Downloading ISIC_0032876...
# Downloading ISIC_0032875...
# Downloading ISIC_0032874...
# Downloading ISIC_0032873...
# Downloading ISIC_0032872...
# Downloading ISIC_0032871...
# Downloading ISIC_0032870...
# Downloading ISIC_0032869...
# Downloading ISIC_0032868...
# Downloading ISIC_0032867...
# Downloading ISIC_0032866...
# Downloading ISIC_0032865...
# Downloading ISIC_0032864...
# Downloading ISIC_0032863...
# Downloading ISIC_0032862...
# Downloading ISIC_0032861...
# Downloading ISIC_0032860...
# Downloading ISIC_0032859...
# Downloading ISIC_0032858...
# Downloading ISIC_0032857...
# Downloading ISIC_0032856...
# Downloading ISIC_0032855...
# Downloading ISIC_0032854...
# Downloading ISIC_0032853...
# Downloading ISIC_0032852...
# Downloading ISIC_0032851...
# Downloading ISIC_0032850...
# Downloading ISIC_0032849...
# Downloading ISIC_0032848...
# Downloading ISIC_0032847...
# Downloading ISIC_0032846...
# Downloading ISIC_0032845...
# Downloading ISIC_0032844...
# Downloading ISIC_0032843...
# Downloading ISIC_0032842...
# Downloading ISIC_0032841...
# Downloading ISIC_0032840...
# Downloading ISIC_0032839...
# Downloading ISIC_0032838...
# Downloading ISIC_0032837...
# Downloading ISIC_0032836...
# Downloading ISIC_0032835...
# Downloading ISIC_0032834...
# Downloading ISIC_0032833...
# Downloading ISIC_0032832...
# Downloading ISIC_0032831...
# Downloading ISIC_0032830...
# Downloading ISIC_0032829...
# Downloading ISIC_0032828...
# Downloading ISIC_0032827...
# Downloading ISIC_0032826...
# Downloading ISIC_0032825...
# Downloading ISIC_0032824...
# Downloading ISIC_0032823...
# Downloading ISIC_0032822...
# Downloading ISIC_0032821...
# Downloading ISIC_0032820...
# Downloading ISIC_0032819...
# Downloading ISIC_0032818...
# Downloading ISIC_0032817...
# Downloading ISIC_0032816...
# Downloading ISIC_0032815...
# Downloading ISIC_0032814...
# Downloading ISIC_0032813...
# Downloading ISIC_0032812...
# Downloading ISIC_0032811...
# Downloading ISIC_0032810...
# Downloading ISIC_0032809...
# Downloading ISIC_0032808...
# Downloading ISIC_0032807...
# Downloading ISIC_0032806...
# Downloading ISIC_0032805...
# Downloading ISIC_0032804...
# Downloading ISIC_0032803...
# Downloading ISIC_0032802...
# Downloading ISIC_0032801...
# Downloading ISIC_0032800...
# Downloading ISIC_0032799...
# Downloading ISIC_0032798...
# Downloading ISIC_0032797...
# Downloading ISIC_0032796...
# Downloading ISIC_0032795...
# Downloading ISIC_0032794...
# Downloading ISIC_0032793...
# Downloading ISIC_0032792...
# Downloading ISIC_0032791...
# Downloading ISIC_0032790...
# Downloading ISIC_0032789...
# Downloading ISIC_0032788...
# Downloading ISIC_0032787...
# Downloading ISIC_0032786...
# Downloading ISIC_0032785...
# Downloading ISIC_0032784...
# Downloading ISIC_0032783...
# Downloading ISIC_0032782...
# Downloading ISIC_0032781...
# Downloading ISIC_0032780...
# Downloading ISIC_0032779...
# Downloading ISIC_0032778...
# Downloading ISIC_0032777...
# Downloading ISIC_0032776...
# Downloading ISIC_0032775...
# Downloading ISIC_0032774...
# Downloading ISIC_0032773...
# Downloading ISIC_0032772...
# Downloading ISIC_0032771...
# Downloading ISIC_0032770...
# Downloading ISIC_0032769...
# Downloading ISIC_0032768...
# Downloading ISIC_0032767...
# Downloading ISIC_0032766...
# Downloading ISIC_0032765...
# Downloading ISIC_0032764...
# Downloading ISIC_0032763...
# Downloading ISIC_0032762...
# Downloading ISIC_0032761...
# Downloading ISIC_0032760...
# Downloading ISIC_0032759...
# Downloading ISIC_0032758...
# Downloading ISIC_0032757...
# Downloading ISIC_0032756...
# Downloading ISIC_0032755...
# Downloading ISIC_0032754...
# Downloading ISIC_0032753...
# Downloading ISIC_0032752...
# Downloading ISIC_0032751...
# Downloading ISIC_0032750...
# Downloading ISIC_0032749...
# Downloading ISIC_0032748...
# Downloading ISIC_0032747...
# Downloading ISIC_0032746...
# Downloading ISIC_0032745...
# Downloading ISIC_0032744...
# Downloading ISIC_0032743...
# Downloading ISIC_0032742...
# Downloading ISIC_0032741...
# Downloading ISIC_0032740...
# Downloading ISIC_0032739...
# Downloading ISIC_0032738...
# Downloading ISIC_0032737...
# Downloading ISIC_0032736...
# Downloading ISIC_0032735...
# Downloading ISIC_0032734...
# Downloading ISIC_0032733...
# Downloading ISIC_0032732...
# Downloading ISIC_0032731...
# Downloading ISIC_0032730...
# Downloading ISIC_0032729...
# Downloading ISIC_0032728...
# Downloading ISIC_0032727...
# Downloading ISIC_0032726...
# Downloading ISIC_0032725...
# Downloading ISIC_0032724...
# Downloading ISIC_0032723...
# Downloading ISIC_0032722...
# Downloading ISIC_0032721...
# Downloading ISIC_0032720...
# Downloading ISIC_0032719...
# Downloading ISIC_0032718...
# Downloading ISIC_0032717...
# Downloading ISIC_0032716...
# Downloading ISIC_0032715...
# Downloading ISIC_0032714...
# Downloading ISIC_0032713...
# Downloading ISIC_0032712...
# Downloading ISIC_0032711...
# Downloading ISIC_0032710...
# Downloading ISIC_0032709...
# Downloading ISIC_0032708...
# Downloading ISIC_0032707...
# Downloading ISIC_0032706...
# Downloading ISIC_0032705...
# Downloading ISIC_0032704...
# Downloading ISIC_0032703...
# Downloading ISIC_0032702...
# Downloading ISIC_0032701...
# Downloading ISIC_0032700...
# Downloading ISIC_0032699...
# Downloading ISIC_0032698...
# Downloading ISIC_0032697...
# Downloading ISIC_0032696...
# Downloading ISIC_0032695...
# Downloading ISIC_0032694...
# Downloading ISIC_0032693...
# Downloading ISIC_0032692...
# Downloading ISIC_0032691...
# Downloading ISIC_0032690...
# Downloading ISIC_0032689...
# Downloading ISIC_0032688...
# Downloading ISIC_0032687...
# Downloading ISIC_0032686...
# Downloading ISIC_0032685...
# Downloading ISIC_0032684...
# Downloading ISIC_0032683...
# Downloading ISIC_0032682...
# Downloading ISIC_0032681...
# Downloading ISIC_0032680...
# Downloading ISIC_0032679...
# Downloading ISIC_0032678...
# Downloading ISIC_0032677...
# Downloading ISIC_0032676...
# Downloading ISIC_0032675...
# Downloading ISIC_0032674...
# Downloading ISIC_0032673...
# Downloading ISIC_0032672...
# Downloading ISIC_0032671...
# Downloading ISIC_0032670...
# Downloading ISIC_0032669...
# Downloading ISIC_0032668...
# Downloading ISIC_0032667...
# Downloading ISIC_0032666...
# Downloading ISIC_0032665...
# Downloading ISIC_0032664...
# Downloading ISIC_0032663...
# Downloading ISIC_0032662...
# Downloading ISIC_0032661...
# Downloading ISIC_0032660...
# Downloading ISIC_0032659...
# Downloading ISIC_0032658...
# Downloading ISIC_0032657...
# Downloading ISIC_0032656...
# Downloading ISIC_0032655...
# Downloading ISIC_0032654...
# Downloading ISIC_0032653...
# Downloading ISIC_0032652...
# Downloading ISIC_0032651...
# Downloading ISIC_0032650...
# Downloading ISIC_0032649...
# Downloading ISIC_0032648...
# Downloading ISIC_0032647...
# Downloading ISIC_0032646...
# Downloading ISIC_0032645...
# Downloading ISIC_0032644...
# Downloading ISIC_0032643...
# Downloading ISIC_0032642...
# Downloading ISIC_0032641...
# Downloading ISIC_0032640...
# Downloading ISIC_0032639...
# Downloading ISIC_0032638...
# Downloading ISIC_0032637...
# Downloading ISIC_0032636...
# Downloading ISIC_0032635...
# Downloading ISIC_0032634...
# Downloading ISIC_0032633...
# Downloading ISIC_0032632...
# Downloading ISIC_0032631...
# Downloading ISIC_0032630...
# Downloading ISIC_0032629...
# Downloading ISIC_0032628...
# Downloading ISIC_0032627...
# Downloading ISIC_0032626...
# Downloading ISIC_0032625...
# Downloading ISIC_0032624...
# Downloading ISIC_0032623...
# Downloading ISIC_0032622...
# Downloading ISIC_0032621...
# Downloading ISIC_0032620...
# Downloading ISIC_0032619...
# Downloading ISIC_0032618...
# Downloading ISIC_0032617...
# Downloading ISIC_0032616...
# Downloading ISIC_0032615...
# Downloading ISIC_0032614...
# Downloading ISIC_0032613...
# Downloading ISIC_0032612...
# Downloading ISIC_0032611...
# Downloading ISIC_0032610...
# Downloading ISIC_0032609...
# Downloading ISIC_0032608...
# Downloading ISIC_0032607...
# Downloading ISIC_0032606...
# Downloading ISIC_0032605...
# Downloading ISIC_0032604...
# Downloading ISIC_0032603...
# Downloading ISIC_0032602...
# Downloading ISIC_0032601...
# Downloading ISIC_0032600...
# Downloading ISIC_0032599...
# Downloading ISIC_0032598...
# Downloading ISIC_0032597...
# Downloading ISIC_0032596...
# Downloading ISIC_0032595...
# Downloading ISIC_0032594...
# Downloading ISIC_0032593...
# Downloading ISIC_0032592...
# Downloading ISIC_0032591...
# Downloading ISIC_0032590...
# Downloading ISIC_0032589...
# Downloading ISIC_0032588...
# Downloading ISIC_0032587...
# Downloading ISIC_0032586...
# Downloading ISIC_0032585...
# Downloading ISIC_0032584...
# Downloading ISIC_0032583...
# Downloading ISIC_0032582...
# Downloading ISIC_0032581...
# Downloading ISIC_0032580...
# Downloading ISIC_0032579...
# Downloading ISIC_0032578...
# Downloading ISIC_0032577...
# Downloading ISIC_0032576...
# Downloading ISIC_0032575...
# Downloading ISIC_0032574...
# Downloading ISIC_0032573...
# Downloading ISIC_0032572...
# Downloading ISIC_0032571...
# Downloading ISIC_0032570...
# Downloading ISIC_0032569...
# Downloading ISIC_0032568...
# Downloading ISIC_0032567...
# Downloading ISIC_0032566...
# Downloading ISIC_0032565...
# Downloading ISIC_0032564...
# Downloading ISIC_0032563...
# Downloading ISIC_0032562...
# Downloading ISIC_0032561...
# Downloading ISIC_0032560...
# Downloading ISIC_0032559...
# Downloading ISIC_0032558...
# Downloading ISIC_0032557...
# Downloading ISIC_0032556...
# Downloading ISIC_0032555...
# Downloading ISIC_0032554...
# Downloading ISIC_0032553...
# Downloading ISIC_0032552...
# Downloading ISIC_0032551...
# Downloading ISIC_0032550...
# Downloading ISIC_0032549...
# Downloading ISIC_0032548...
# Downloading ISIC_0032547...
# Downloading ISIC_0032546...
# Downloading ISIC_0032545...
# Downloading ISIC_0032544...
# Downloading ISIC_0032543...
# Downloading ISIC_0032542...
# Downloading ISIC_0032541...
# Downloading ISIC_0032540...
# Downloading ISIC_0032539...
# Downloading ISIC_0032538...
# Downloading ISIC_0032537...
# Downloading ISIC_0032536...
# Downloading ISIC_0032535...
# Downloading ISIC_0032534...
# Downloading ISIC_0032533...
# Downloading ISIC_0032532...
# Downloading ISIC_0032531...
# Downloading ISIC_0032530...
# Downloading ISIC_0032529...
# Downloading ISIC_0032528...
# Downloading ISIC_0032527...
# Downloading ISIC_0032526...
# Downloading ISIC_0032525...
# Downloading ISIC_0032524...
# Downloading ISIC_0032523...
# Downloading ISIC_0032522...
# Downloading ISIC_0032521...
# Downloading ISIC_0032520...
# Downloading ISIC_0032519...
# Downloading ISIC_0032518...
# Downloading ISIC_0032517...
# Downloading ISIC_0032516...
# Downloading ISIC_0032515...
# Downloading ISIC_0032514...
# Downloading ISIC_0032513...
# Downloading ISIC_0032512...
# Downloading ISIC_0032511...
# Downloading ISIC_0032510...
# Downloading ISIC_0032509...
# Downloading ISIC_0032508...
# Downloading ISIC_0032507...
# Downloading ISIC_0032506...
# Downloading ISIC_0032505...
# Downloading ISIC_0032504...
# Downloading ISIC_0032503...
# Downloading ISIC_0032502...
# Downloading ISIC_0032501...
# Downloading ISIC_0032500...
# Downloading ISIC_0032499...
# Downloading ISIC_0032498...
# Downloading ISIC_0032497...
# Downloading ISIC_0032496...
# Downloading ISIC_0032495...
# Downloading ISIC_0032494...
# Downloading ISIC_0032493...
# Downloading ISIC_0032492...
# Downloading ISIC_0032491...
# Downloading ISIC_0032490...
# Downloading ISIC_0032489...
# Downloading ISIC_0032488...
# Downloading ISIC_0032487...
# Downloading ISIC_0032486...
# Downloading ISIC_0032485...
# Downloading ISIC_0032484...
# Downloading ISIC_0032483...
# Downloading ISIC_0032482...
# Downloading ISIC_0032481...
# Downloading ISIC_0032480...
# Downloading ISIC_0032479...
# Downloading ISIC_0032478...
# Downloading ISIC_0032477...
# Downloading ISIC_0032476...
# Downloading ISIC_0032475...
# Downloading ISIC_0032474...
# Downloading ISIC_0032473...
# Downloading ISIC_0032472...
# Downloading ISIC_0032471...
# Downloading ISIC_0032470...
# Downloading ISIC_0032469...
# Downloading ISIC_0032468...
# Downloading ISIC_0032467...
# Downloading ISIC_0032466...
# Downloading ISIC_0032465...
# Downloading ISIC_0032464...
# Downloading ISIC_0032463...
# Downloading ISIC_0032462...
# Downloading ISIC_0032461...
# Downloading ISIC_0032460...
# Downloading ISIC_0032459...
# Downloading ISIC_0032458...
# Downloading ISIC_0032457...
# Downloading ISIC_0032456...
# Downloading ISIC_0032455...
# Downloading ISIC_0032454...
# Downloading ISIC_0032453...
# Downloading ISIC_0032452...
# Downloading ISIC_0032451...
# Downloading ISIC_0032450...
# Downloading ISIC_0032449...
# Downloading ISIC_0032448...
# Downloading ISIC_0032447...
# Downloading ISIC_0032446...
# Downloading ISIC_0032445...
# Downloading ISIC_0032444...
# Downloading ISIC_0032443...
# Downloading ISIC_0032442...
# Downloading ISIC_0032441...
# Downloading ISIC_0032440...
# Downloading ISIC_0032439...
# Downloading ISIC_0032438...
# Downloading ISIC_0032437...
# Downloading ISIC_0032436...
# Downloading ISIC_0032435...
# Downloading ISIC_0032434...
# Downloading ISIC_0032433...
# Downloading ISIC_0032432...
# Downloading ISIC_0032431...
# Downloading ISIC_0032430...
# Downloading ISIC_0032429...
# Downloading ISIC_0032428...
# Downloading ISIC_0032427...
# Downloading ISIC_0032426...
# Downloading ISIC_0032425...
# Downloading ISIC_0032424...
# Downloading ISIC_0032423...
# Downloading ISIC_0032422...
# Downloading ISIC_0032421...
# Downloading ISIC_0032420...
# Downloading ISIC_0032419...
# Downloading ISIC_0032418...
# Downloading ISIC_0032417...
# Downloading ISIC_0032416...
# Downloading ISIC_0032415...
# Downloading ISIC_0032414...
# Downloading ISIC_0032413...
# Downloading ISIC_0032412...
# Downloading ISIC_0032411...
# Downloading ISIC_0032410...
# Downloading ISIC_0032409...
# Downloading ISIC_0032408...
# Downloading ISIC_0032407...
# Downloading ISIC_0032406...
# Downloading ISIC_0032405...
# Downloading ISIC_0032404...
# Downloading ISIC_0032403...
# Downloading ISIC_0032402...
# Downloading ISIC_0032401...
# Downloading ISIC_0032400...
# Downloading ISIC_0032399...
# Downloading ISIC_0032398...
# Downloading ISIC_0032397...
# Downloading ISIC_0032396...
# Downloading ISIC_0032395...
# Downloading ISIC_0032394...
# Downloading ISIC_0032393...
# Downloading ISIC_0032392...
# Downloading ISIC_0032391...
# Downloading ISIC_0032390...
# Downloading ISIC_0032389...
# Downloading ISIC_0032388...
# Downloading ISIC_0032387...
# Downloading ISIC_0032386...
# Downloading ISIC_0032385...
# Downloading ISIC_0032384...
# Downloading ISIC_0032383...
# Downloading ISIC_0032382...
# Downloading ISIC_0032381...
# Downloading ISIC_0032380...
# Downloading ISIC_0032379...
# Downloading ISIC_0032378...
# Downloading ISIC_0032377...
# Downloading ISIC_0032376...
# Downloading ISIC_0032375...
# Downloading ISIC_0032374...
# Downloading ISIC_0032373...
# Downloading ISIC_0032372...
# Downloading ISIC_0032371...
# Downloading ISIC_0032370...
# Downloading ISIC_0032369...
# Downloading ISIC_0032368...
# Downloading ISIC_0032367...
# Downloading ISIC_0032366...
# Downloading ISIC_0032365...
# Downloading ISIC_0032364...
# Downloading ISIC_0032363...
# Downloading ISIC_0032362...
# Downloading ISIC_0032361...
# Downloading ISIC_0032360...
# Downloading ISIC_0032359...
# Downloading ISIC_0032358...
# Downloading ISIC_0032357...
# Downloading ISIC_0032356...
# Downloading ISIC_0032355...
# Downloading ISIC_0032354...
# Downloading ISIC_0032353...
# Downloading ISIC_0032352...
# Downloading ISIC_0032351...
# Downloading ISIC_0032350...
# Downloading ISIC_0032349...
# Downloading ISIC_0032348...
# Downloading ISIC_0032347...
# Downloading ISIC_0032346...
# Downloading ISIC_0032345...
# Downloading ISIC_0032344...
# Downloading ISIC_0032343...
# Downloading ISIC_0032342...
# Downloading ISIC_0032341...
# Downloading ISIC_0032340...
# Downloading ISIC_0032339...
# Downloading ISIC_0032338...
# Downloading ISIC_0032337...
# Downloading ISIC_0032336...
# Downloading ISIC_0032335...
# Downloading ISIC_0032334...
# Downloading ISIC_0032333...
# Downloading ISIC_0032332...
# Downloading ISIC_0032331...
# Downloading ISIC_0032330...
# Downloading ISIC_0032329...
# Downloading ISIC_0032328...
# Downloading ISIC_0032327...
# Downloading ISIC_0032326...
# Downloading ISIC_0032325...
# Downloading ISIC_0032324...
# Downloading ISIC_0032323...
# Downloading ISIC_0032322...

# %%
folder = "ISIC_IMAGES_TASK_3"
num_files = len([f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))])

print("Expected 10015")
print(f"Got: {num_files}")

# %% [markdown]
# Explore how to identify a picture as benign or malignant.
#
# First the field "benign_malignant" seems apropriate to do this testing,so we will see if all the entries of the dataset have this value

# %%
for entry in results:
    isic_id = entry.get("isic_id", "UNKNOWN_ID")
    clinical = entry.get("metadata", {}).get("clinical", {})

    missing = []
    if "lesion_id" not in clinical:
        missing.append("lesion_id")
    if "benign_malignant" not in clinical:
        missing.append("benign_malignant")

    if missing:
        print(f"{isic_id} is missing: {', '.join(missing)}")

# %% [markdown]
# Conclusion:Some of theme do not have this attribute so we need to find another for theme.The attribute diagnosis_1 seems good for this task, we will see wich values can it be.

# %%
missing_diagnosis_1_values = set()

for entry in results:
    clinical = entry.get("metadata", {}).get("clinical", {})

    if "benign_malignant" not in clinical:
        diag1 = clinical.get("diagnosis_1")
        if diag1:
            missing_diagnosis_1_values.add(diag1)

print(" Unique 'diagnosis_1' values for entries missing 'benign_malignant':")
for value in sorted(missing_diagnosis_1_values):
    print("-", value)

# %% [markdown]
# We can conclude that if they dont have the benign_malignant atribute, we can use diagnosis_1 since it provides information about the cancer.
# diagnosis_1 can take the value "Indeterminate", we will discard these values since they do not identify the disease.

# %% [markdown]
# Put into the file **lesions.csv** with:
#
# *   file -> isic_id.jpg
# *   patient -> lesion_id
# *   label
#       - 0 ("benign_malignant": "benign")
#       - 1 ("benign_malignant": "malignant")

# %%
import pandas as pd

rows = []

for result in results:
    try:
        isic_id = result["isic_id"]
        filename = f"{isic_id}.jpg"
        clinical = result["metadata"]["clinical"]
        patient = clinical.get("lesion_id", "unknown")

        benign_malignant = clinical.get("benign_malignant")
        diagnosis_1 = clinical.get("diagnosis_1", "")

        # Decide label based on available info
        if benign_malignant:
            label = 1 if benign_malignant.lower() == "malignant" else 0
        elif diagnosis_1 == "Benign":
            label = 0
        elif diagnosis_1 == "Malignant":
            label = 1
        else:  # Indeterminate or unknown
            continue  # ❌ Skip

        rows.append({
            "file": filename,
            "patient": patient,
            "label": label
        })

    except Exception as e:
        print(f"Skipped entry {result.get('isic_id', 'UNKNOWN')} due to error: {e}")

# Create DataFrame and write to CSV
df = pd.DataFrame(rows)
df.to_csv("lesions.csv", index=False)

print("Saved lesions.csv with", len(df), "entries.")

# %% [markdown]
# **Load dataset kaggle**

# %%
import kagglehub
import os
import shutil
from tqdm import tqdm

# Step 1: Download the dataset
path = kagglehub.dataset_download("kmader/skin-cancer-mnist-ham10000")
print("✅ Dataset downloaded to:", path)

# Step 2: Create destination folder
dst_dir = "KAGGLE_IMAGES_ham10000"
os.makedirs(dst_dir, exist_ok=True)

# Step 3: Walk the directory and copy .jpg files
count = 0
for root, _, files in os.walk(path):
    for file in files:
        if file.lower().endswith(".jpg"):
            src_path = os.path.join(root, file)
            dst_path = os.path.join(dst_dir, file)
            shutil.copy2(src_path, dst_path)
            count += 1

print(f"Copied {count} .jpg files into '{dst_dir}'")
meta_src = os.path.join(path, "HAM10000_metadata.csv")
meta_dst = os.path.join(dst_dir, "HAM10000_metadata.csv")
shutil.copy2(meta_src, meta_dst)
print("Copied metadata file to:", dst_dir)

# %% [markdown]
# Upon further investigation, we identified an error in our dataset selection. The HAM10000 dataset completely overlaps with the ISIC 2018 Task 3 dataset, as HAM10000 images are included within ISIC. Therefore, we have decided to exclude HAM10000 from our analysis.
#
# The code below demonstrates this overlap by comparing the image IDs previously retrieved from ISIC with those found in the HAM10000 metadata.

# %%
metadata_path = "KAGGLE_IMAGES_ham10000/HAM10000_metadata.csv"
df = pd.read_csv(metadata_path)

metadata_ids = set(df["image_id"])

all_ids_set = set(all_ids)

missing_ids = metadata_ids - all_ids_set

print(f"Found {len(missing_ids)} image_ids in HAM10000 metadata that are not in all_ids:")
for mid in sorted(missing_ids):
    print("-", mid)

# %% [markdown]
# Split into 70/15/15

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your lesions.csv
df = pd.read_csv("lesions.csv")

# Step 1: Get unique patients
unique_patients = df["patient"].unique()

# Step 2: Split patients → 70% train, 30% temp (val+test)
train_patients, temp_patients = train_test_split(
    unique_patients, test_size=0.30, random_state=42
)

# Step 3: Split temp → 50/50 into val and test (15% each)
val_patients, test_patients = train_test_split(
    temp_patients, test_size=0.50, random_state=42
)

# Step 4: Create splits by filtering on patient ID
train_df = df[df["patient"].isin(train_patients)].reset_index(drop=True)
val_df = df[df["patient"].isin(val_patients)].reset_index(drop=True)
test_df = df[df["patient"].isin(test_patients)].reset_index(drop=True)

# Step 5: Save them to CSV (optional)
train_df.to_csv("lesions_train.csv", index=False)
val_df.to_csv("lesions_val.csv", index=False)
test_df.to_csv("lesions_test.csv", index=False)

# Summary
print(f"Train: {len(train_df)} samples")
print(f"Val:   {len(val_df)} samples")
print(f"Test:  {len(test_df)} samples")

# %%
import os
from PIL import Image
import torch
from torchvision import transforms
from tqdm import tqdm

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.9, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(0.1, 0.1, 0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

# %%
from torch.utils.data import Dataset

class SkinCancerDataset(Dataset):
    def __init__(self, dataframe, image_dir, transform=None):
        self.df = dataframe
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.image_dir, row["file"])
        label = torch.tensor(row["label"], dtype=torch.float32)

        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        return image, label

# %%
from torch.utils.data import DataLoader

train_dataset = SkinCancerDataset(train_df, "ISIC_IMAGES_TASK_3", transform=train_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=2
)

# %%
import timm
import torch.nn as nn

model = timm.create_model(
    "efficientnet_b0",
    pretrained=True,
    num_classes=1  # output neuron
)

# %%
import torch
import torch.nn as nn

class FocalBCELoss(nn.Module):
    def __init__(self, gamma=2):
        super().__init__()
        self.gamma = gamma
        self.bce = nn.BCEWithLogitsLoss(reduction='none')

    def forward(self, input, target):
        bce = self.bce(input, target)
        prob = torch.sigmoid(input)
        focal = (1 - prob) ** self.gamma
        return (focal * bce).mean()

# %%
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR

criterion = FocalBCELoss(gamma=2.0)
optimizer = AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=30)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    roc_auc_score, balanced_accuracy_score,
    precision_recall_fscore_support
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

val_dataset = SkinCancerDataset(val_df, "ISIC_IMAGES_TASK_3", transform=train_transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)

n_epochs = 10
train_losses = np.zeros(n_epochs)
val_losses = np.zeros(n_epochs)
val_aurocs = np.zeros(n_epochs)
val_f1s = np.zeros(n_epochs)
val_bal_accs = np.zeros(n_epochs)

for epoch in range(n_epochs):
    model.train()
    running_loss = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        logits = model(images).squeeze()
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    train_losses[epoch] = running_loss / len(train_loader.dataset)
    scheduler.step()

    # Step 5: Inference + Step 6: Metrics
    model.eval()
    all_probs = []
    all_labels = []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            logits = model(images).squeeze()
            probs = torch.sigmoid(logits).cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.numpy())

    y_true = np.array(all_labels)
    y_prob = np.array(all_probs)
    y_pred = (y_prob > 0.5).astype(int)

    val_losses[epoch] = criterion(torch.tensor(y_prob), torch.tensor(y_true)).item()
    val_aurocs[epoch] = roc_auc_score(y_true, y_prob)
    val_bal_accs[epoch] = balanced_accuracy_score(y_true, y_pred)
    _, _, val_f1s[epoch], _ = precision_recall_fscore_support(y_true, y_pred, average='binary')

    print(f"Epoch {epoch+1:2d}: Train Loss = {train_losses[epoch]:.4f} | "
          f"Val Loss = {val_losses[epoch]:.4f} | AUROC = {val_aurocs[epoch]:.4f} | "
          f"F1 = {val_f1s[epoch]:.4f} | Balanced Acc = {val_bal_accs[epoch]:.4f}")



# Loss plot
plt.figure(figsize=(10, 4))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.title("Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# Metrics plot
plt.figure(figsize=(10, 4))
plt.plot(val_aurocs, label="AUROC")
plt.plot(val_f1s, label="F1 Score")
plt.plot(val_bal_accs, label="Balanced Accuracy")
plt.title("Validation Metrics Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.legend()
plt.grid(True)
plt.show()
